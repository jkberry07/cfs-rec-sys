# %%
from Programs import Program, get_semantic_embedding, get_tone_embedding
from WebScrapeText import split_sent
import pickle
import numpy as np
import tensorflow as tf
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\wmmjk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
with open('program_list.pkl', 'rb') as file:
    program_list = pickle.load(file)

# %%
UserText = ['I want to be healthy and happy', 'I feel stressed, but I don\'t know what to do with it','I care deeply about growing as a person'] #this will be input from the user

# %%
def compare_user_prog(user_text,prog_list):
    """Generate embeddings for user text, compare to program text"""
    N_similarities = 5 #How many similarity scores to use in averaging
    N_progs = len(prog_list)
    user_text_split = []
    for text in user_text: #split user text up into sentences
        user_text_split.append(split_sent(text))
    user_sem_embeddings = [get_semantic_embedding(text) for text in user_text_split]
    user_tone_embeddings = [get_tone_embedding(text) for text in user_text_split]
    N_user_embeddings = len(user_sem_embeddings)
    top_sem_similarities_indxs = np.zeros((N_progs,N_user_embeddings,N_similarities)) # index of the top N most similar program sentences to each user sentence
    top_sem_similarities_scores = np.zeros((N_progs,N_user_embeddings,N_similarities))# score of the top N most similar program sentences to each user sentence
    top_tone_similarities_indxs = np.zeros((N_progs,N_user_embeddings,N_similarities))# index of the top N most similar program sentences to each user sentence
    top_tone_similarities_scores = np.zeros((N_progs,N_user_embeddings,N_similarities))# score of the top N most similar program sentences to each user sentence
    for p in range(N_progs):
        prog = prog_list[p]
        for i in range(N_user_embeddings): #for the ith user sentence
            prog_sem_similarities = np.zeros(len(prog.text))
            prog_tone_similarities = np.zeros(len(prog.text))
            for j in range(len(prog.text)): #for the jth program sentence
                prog_sem_similarities[j] = -tf.keras.losses.cosine_similarity(
                    user_sem_embeddings[i],prog.semantic_embeddings[j]) #calculate similarity (flip the sign bec it's defined a negative for use as a loss in tensorflow
                prog_tone_similarities[j] = -tf.keras.losses.cosine_similarity(
                    user_tone_embeddings[i],prog.tone_embeddings[j])
            indices_sem = tf.argsort(prog_sem_similarities, direction = 'DESCENDING') #sort by similarity
            indices_tone = tf.argsort(prog_tone_similarities, direction = 'DESCENDING') #sort by similarity
            top_sem_similarities_indxs[p,i,:] = indices_sem[:N_similarities] #store only the top N most similar program sentences
            top_sem_similarities_scores[p,i,:] = [prog_sem_similarities[indx] for indx in indices_sem[:N_similarities]] #pull out the scores for the top N most similar
            top_tone_similarities_indxs[p,i,:] = indices_tone[:N_similarities] #store only the top N most similar
            top_tone_similarities_scores[p,i,:] = [prog_tone_similarities[indx] for indx in indices_tone[:N_similarities]] #pull out the scores for the top N most similar
    return top_sem_similarities_indxs, top_sem_similarities_scores,top_tone_similarities_indxs, top_tone_similarities_scores

# %%
topsem_indx,topsem_score,toptone_indx,toptone_score = compare_user_prog(UserText,program_list)

# %%
N_progs = len(program_list)
N_user_embeddings = np.shape(topsem_indx)[1]
N_similarities = 5
for p in range(N_progs):
    prog = program_list[p]
    print(prog.name)
    for i in range(N_user_embeddings):
        print(UserText[i])
        for n in range(N_similarities):
            sem_indx = int(topsem_indx[p,i,n])
            print(f"Program Semantic Sentence #{n+1}: {prog.text[sem_indx]} Semantic Score: {topsem_score[p,i,n]: .4f}")
        print('')
        for n in range(N_similarities):
            tone_indx = int(toptone_indx[p,i,n])
            print(f"Program Tone Sentence #{n+1}: {prog.text[tone_indx]} Tone Score: {toptone_score[p,i,n]: .4f}")
        print('\n')
    print('\n\n\n')
# Out:
# Primal Trust
# I want to be healthy and happy
# Program Semantic Sentence #1: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Semantic Score:  0.3873
# Program Semantic Sentence #2: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Semantic Score:  0.2453
# Program Semantic Sentence #3: Find Your Community. Find Your Strength Semantic Score:  0.2363
# Program Semantic Sentence #4: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Semantic Score:  0.2337
# Program Semantic Sentence #5: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Semantic Score:  0.1861
#
# Program Tone Sentence #1: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Tone Score:  0.7716
# Program Tone Sentence #2: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Tone Score:  0.7202
# Program Tone Sentence #3: Find Your Community. Find Your Strength Tone Score:  0.6418
# Program Tone Sentence #4: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Tone Score:  0.4003
# Program Tone Sentence #5: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Tone Score:  0.2253
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: Find Your Community. Find Your Strength Semantic Score:  0.2199
# Program Semantic Sentence #2: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Semantic Score:  0.2141
# Program Semantic Sentence #3: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Semantic Score:  0.1945
# Program Semantic Sentence #4: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Semantic Score:  0.1813
# Program Semantic Sentence #5: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Semantic Score:  0.0730
#
# Program Tone Sentence #1: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Tone Score:  0.8065
# Program Tone Sentence #2: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Tone Score:  0.5707
# Program Tone Sentence #3: Find Your Community. Find Your Strength Tone Score:  0.1635
# Program Tone Sentence #4: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Tone Score:  0.1210
# Program Tone Sentence #5: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Tone Score:  0.1064
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Semantic Score:  0.4099
# Program Semantic Sentence #2: Find Your Community. Find Your Strength Semantic Score:  0.3649
# Program Semantic Sentence #3: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Semantic Score:  0.3559
# Program Semantic Sentence #4: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Semantic Score:  0.3096
# Program Semantic Sentence #5: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Semantic Score:  0.2708
#
# Program Tone Sentence #1: What truly sets Primal Trust apart is more than just its groundbreaking approach to healing; it’s the creation of a deeply connected community. Tone Score:  0.9018
# Program Tone Sentence #2: Find Your Community. Find Your Strength Tone Score:  0.8567
# Program Tone Sentence #3: Here, you’ll engage with like-minded individuals in a supportive space, sharing weekly classes and interactive sessions with Dr. Cat and leading mentors. Tone Score:  0.8515
# Program Tone Sentence #4: If you’re navigating a labyrinth of lab tests, pills, and platitudes, Primal Trust resonates with your struggle. Tone Score:  0.6637
# Program Tone Sentence #5: Are you tired of feeling unheard and unsupported in your quest for health and vitality? Tone Score:  0.3933
#
#
#
#
#
#
# ANS Rewire
# I want to be healthy and happy
# Program Semantic Sentence #1: Take the daily action steps to move you forward. Semantic Score:  0.3919
# Program Semantic Sentence #2: It is about guiding you to explore answers to the above questions and to seek additional help from health care professionals where needed as part of your holistic recovery action plan, to tip your nervous system back into normal functioning. Semantic Score:  0.3059
# Program Semantic Sentence #3: This category is made up of specific education and strategies to reduce these triggers to help you create a healing environment and start your journey towards recovery. Semantic Score:  0.2971
# Program Semantic Sentence #4: So whilst all people share common challenges and dysfunctions, that often require a common approach, we recognise that everyone still has some different needs. Semantic Score:  0.2930
# Program Semantic Sentence #5: This is why there is no single effective fix-all treatment for these conditions that works for everyone, no easy cure. Semantic Score:  0.2929
#
# Program Tone Sentence #1: It has been wonderful to get so much positive feedback about CFS Unravelled over the years. Tone Score:  0.7643
# Program Tone Sentence #2: The training includes: Finally there are also some additional video lessons that address circumstances where some people might seek specific medical treatments, including: The lessons help put these additional treatments into context, provide some background information and share some key distinctions for success. Tone Score:  0.7416
# Program Tone Sentence #3: These assist in bringing about desirable changes in brainwave activity to encourage states of relaxation, deep meditation or sleep. Tone Score:  0.7393
# Program Tone Sentence #4: And once they are able to somewhat engage their muscles with their mind, the learning can accelerate. Tone Score:  0.7330
# Program Tone Sentence #5: Even though most physicians trained last century were emphatically told that the brain is fixed by the time we reach adulthood, wonderful research scientists like Dr Michael Merzenich have proven that this is not the case and opened up the science on neuroplasticity. Tone Score:  0.7285
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: Learn what you need to do and how to do it. Semantic Score:  0.2944
# Program Semantic Sentence #2: Of course, inappropriate responses to psychological stressors can also be retrained, but this has been long-known and much more acceptable in the field of psychology. Semantic Score:  0.2806
# Program Semantic Sentence #3: This category is made up of specific education and strategies to reduce these triggers to help you create a healing environment and start your journey towards recovery. Semantic Score:  0.2773
# Program Semantic Sentence #4: BRAIN TRAINING! Semantic Score:  0.2492
# Program Semantic Sentence #5: What do you do? Semantic Score:  0.2408
#
# Program Tone Sentence #1: And of course, anyone who has experienced chronic pain (research has shown that the ongoing pain in fibromyalgia is primarily caused by central sensitisation where the brain experiences pain more strongly than in normal healthy people), brain fog, irritability, mood swings and sensitivity to lights, sounds and touch, can clearly see that there are issues in how the brain functions. Tone Score:  0.8400
# Program Tone Sentence #2: In a recent recovery snippet, I spoke about the problem with overwhelm of information when it comes to ME/CFS/Fibromyalgia. Tone Score:  0.8297
# Program Tone Sentence #3: I often share this one about ME/CFS/Fibromyalgia/POTS/MCS recovery: Imagine you come home, and your kitchen is flooded with water. Tone Score:  0.8177
# Program Tone Sentence #4: A good example of this is stroke victims, where a part of the brain stops working leaving them unable to perform physical activities like walking or speaking. Tone Score:  0.8081
# Program Tone Sentence #5: And it made me reflect on my own efforts to help the wider ME/CFS/Fibromyalgia community including publishing CFS Unravelled 3.5 years ago. Tone Score:  0.8013
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: Take the daily action steps to move you forward. Semantic Score:  0.3998
# Program Semantic Sentence #2: So whilst all people share common challenges and dysfunctions, that often require a common approach, we recognise that everyone still has some different needs. Semantic Score:  0.3457
# Program Semantic Sentence #3: This is why the lessons are delivered one day at a time, so that you can build on your knowledge and give yourself time to take the action you need to recover. Semantic Score:  0.3112
# Program Semantic Sentence #4: This includes: The lessons are strongly focussed on understanding the reasons behind the differences in people’s experiences. Semantic Score:  0.3092
# Program Semantic Sentence #5: In other words, it is about understanding the answer to this question: Semantic Score:  0.3009
#
# Program Tone Sentence #1: This includes: The lessons are strongly focussed on understanding the reasons behind the differences in people’s experiences. Tone Score:  0.8891
# Program Tone Sentence #2: That is why education and understanding are so heavily featured in the ANS REWIRE program. Tone Score:  0.8822
# Program Tone Sentence #3: It's important that you feel comfortable with the Pros and Cons of the program and make a commitment to the process when you enrol. Tone Score:  0.8687
# Program Tone Sentence #4: So not only is it about attempting to engage in movement with our mind, but also the feedback from our body. Tone Score:  0.8657
# Program Tone Sentence #5: The daily action steps that are part of the program, vary depending on the topic of the lesson. Tone Score:  0.8653
#
#
#
#
#
#
# re-origin
# I want to be healthy and happy
# Program Semantic Sentence #1: You can re-train your brain toward health with a few simple techniques. Semantic Score:  0.3573
# Program Semantic Sentence #2: Instead of focusing on what you can’t do, ask: “What small action can I take today that supports my personal growth and health?” Mindfulness and brain retraining practices help you develop new associations with your symptoms and shift into a more accepting mindset over time. Semantic Score:  0.3363
# Program Semantic Sentence #3: The only thing better than realizing you can heal yourself… is meeting awesome people who are already doing it. Semantic Score:  0.3232
# Program Semantic Sentence #4: If you are struggling with a chronic illness and ready to move towards healing, learn more about the re-origin program here. Semantic Score:  0.3186
# Program Semantic Sentence #5: Give yourself the gift of self-healing. Semantic Score:  0.3119
#
# Program Tone Sentence #1: The re-origin program is a science-based, self-directed neuroplasticity training program with a supportive community & coaching. Tone Score:  0.7743
# Program Tone Sentence #2: What Makes re-origin Unique: drug-free, evidence-based neuroplasticity training, designed by Ph.D. neuroscientists & doctors, vibrant community via web and mobile app, Live Q&As, topical deep dives, guided online workshops, a holistic approach to mental & physical health. Tone Score:  0.7669
# Program Tone Sentence #3: When you join the re-origin program, you’ll automatically enter the club of super-powered self-healers who want you to succeed. Tone Score:  0.7584
# Program Tone Sentence #4: This is really exciting information, as it means that we can actually train our brain to let go of unfavorable neural pathways, replacing them with beneficial neural pathways. Tone Score:  0.7542
# Program Tone Sentence #5: You can join weekly group calls, group coaching, and virtual events to encourage you and keep you on track. Tone Score:  0.7513
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: Say to yourself: “This is hard, and I’m doing my best,” or “I can feel this emotion without it controlling me.” These phrases foster true acceptance and soothe the nervous system. Semantic Score:  0.4601
# Program Semantic Sentence #2: The combination of stressors essentially overwhelms the brain, causing it to go into an extreme survival mode in which it’s hypersensitive and hyper-reactive. Semantic Score:  0.3760
# Program Semantic Sentence #3: Instead of focusing on what you can’t do, ask: “What small action can I take today that supports my personal growth and health?” Mindfulness and brain retraining practices help you develop new associations with your symptoms and shift into a more accepting mindset over time. Semantic Score:  0.3627
# Program Semantic Sentence #4: Chronic stress, fear, and resistance can keep the nervous system in a state of hypervigilance. Semantic Score:  0.3369
# Program Semantic Sentence #5: Give yourself the gift of self-healing. Semantic Score:  0.3266
#
# Program Tone Sentence #1: Chronic illness often creates uncertainty, loss, and profound shifts in identity. Tone Score:  0.8710
# Program Tone Sentence #2: Recovery from limbic system impairments, commonly resulting in fibromyalgia, CFS/ME, and depression. Tone Score:  0.8637
# Program Tone Sentence #3: Designed for people suffering from anxiety, depression, long COVID, Lyme Disease, chronic fatigue syndrome, multiple chemical sensitivity, fibromyalgia, chronic pain, and many other conditions. Tone Score:  0.8620
# Program Tone Sentence #4: Changes to this system can lead to a wide variety of negative symptoms and conditions, such as depression, anxiety, OCD, sensitivities, chronic pain, and chronic fatigue syndrome, just to name a few. Tone Score:  0.8511
# Program Tone Sentence #5: In many cases, limbic system impairments arise when someone experiences a traumatic event while their chronic stress load is already high. Tone Score:  0.8351
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: Instead, it becomes your foundation for growth. Semantic Score:  0.5036
# Program Semantic Sentence #2: This ability to change helps promote: The ability to learn new things. Semantic Score:  0.4120
# Program Semantic Sentence #3: For many individuals, a turning point in their healing path comes not from trying to change their condition but from changing their relationship with it. Semantic Score:  0.4068
# Program Semantic Sentence #4: Talking to others, sharing your experience, and receiving compassion can help you feel accepted and understood. Semantic Score:  0.3766
# Program Semantic Sentence #5: Rather than trying to change these internal experiences, ACT invites individuals to live in alignment with their values—despite the presence of pain. Semantic Score:  0.3753
#
# Program Tone Sentence #1: Talking to others, sharing your experience, and receiving compassion can help you feel accepted and understood. Tone Score:  0.9013
# Program Tone Sentence #2: The re-origin program is designed to help you change your relationship with your chronic illness while cultivating opportunities for healing and growth. Tone Score:  0.8906
# Program Tone Sentence #3: The main idea of acceptance is acknowledging and allowing experiences, emotions, or situations as they are—without judgment or resistance—so we can respond with clarity, compassion, and purpose. Tone Score:  0.8885
# Program Tone Sentence #4: This ability to change helps promote: The ability to learn new things. Tone Score:  0.8880
# Program Tone Sentence #5: Plus, re-origin offers access to a community and coaching specifically geared towards helping people retrain their own brains and return to feeling like themselves. Tone Score:  0.8818
#
#
#
#
#
#
# The Edison Effect
# I want to be healthy and happy
# Program Semantic Sentence #1: Whatever we do, we must try to help the body return to homeostasis. Semantic Score:  0.3595
# Program Semantic Sentence #2: With my health restored, I am now living my dreams of nomadically traveling the world! Semantic Score:  0.3082
# Program Semantic Sentence #3: Yet, in this amazing technological age, we SEE people getting well, so we know it's possible. Semantic Score:  0.3047
# Program Semantic Sentence #4: A binge eating disorder. Semantic Score:  0.3040
# Program Semantic Sentence #5: I was always getting sick. Semantic Score:  0.2731
#
# Program Tone Sentence #1: Connection is the source of all joy. Tone Score:  0.8142
# Program Tone Sentence #2: With my health restored, I am now living my dreams of nomadically traveling the world! Tone Score:  0.8124
# Program Tone Sentence #3: Receive notification for open enrollment periods for The Edison Effect, as well as carefully curated guidance, insights of living/loving & healing from Anj by joining her newsletter. Tone Score:  0.7952
# Program Tone Sentence #4: In this interview with Raelan Agle, I share my journey with MECFS; the good, the bad, the ugly, the beautiful, and most of all, the redemption. Tone Score:  0.7943
# Program Tone Sentence #5: Managed properly, I can do and be amazing things in this world; offering a unique gift that is radiant in splendor when shared. Tone Score:  0.7743
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: A stress response that through conditioning and through crashes, has become more highly sensitive, resulting in a greater imbalance in the way it's triggered, and also greater physiological distress, CAN be reshaped through neuroplasticity and returned to normal. Semantic Score:  0.3742
# Program Semantic Sentence #2: What I was taught at the institute, is that because homeostasis has been lost, and the stress response and rest/digest response are both not working properly, we must work as we can to normalize the stress response, so the body can find balance. Semantic Score:  0.3503
# Program Semantic Sentence #3: However, the reason we work with the ANS the most, is because, without dealing with our stress response, all the other systems which can be so greatly impacted by holistic methods and functional medicine (like the $15,000 I spent on HBOT and ozone therapy which truly helped), will get shot to hell if we have a huge stress trigger again. Semantic Score:  0.3092
# Program Semantic Sentence #4: All the other systems however, will continue to trigger each other, and can in it of themselves, trigger the stress response. Semantic Score:  0.3007
# Program Semantic Sentence #5: If you're in need of guidance, support, have questions about my coaching, or just need someone to listen, feel free to book a discovery call with me. Semantic Score:  0.2746
#
# Program Tone Sentence #1: It made me resentful and melancholy. Tone Score:  0.8689
# Program Tone Sentence #2: After a lifetime of trauma, heartache and distress, I had my first crash in 2018, which led to pushing and crashing until 2021, when a severe crash left me both neurologically and physically crippled. Tone Score:  0.8578
# Program Tone Sentence #3: Looking back now, I experienced fatigue as early as my teens, and it's rare to find a picture of me as a kid without a tissue in hand. Tone Score:  0.8360
# Program Tone Sentence #4: Without the tools, I experienced at young age,  great anxiety and fear about the world around me. Tone Score:  0.8238
# Program Tone Sentence #5: I was always getting sick. Tone Score:  0.8000
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: I was a tiny person with enormous feelings. Semantic Score:  0.4941
# Program Semantic Sentence #2: This sensitivity also made me an incredible artist, a wonderful story-teller, a poet and composer, and an endlessly curious, open-hearted soul, who is capable of giving life to other's experiences in word and song. Semantic Score:  0.4445
# Program Semantic Sentence #3: Everywhere I go, I aim to inspire those I meet to step into their authenticity, and live with unshakeable joy. Semantic Score:  0.4242
# Program Semantic Sentence #4: It made me someone people loved to talk to; to vent to, to lean on. Semantic Score:  0.4150
# Program Semantic Sentence #5: Best of all, this sensitivity, mixed with a gift for language, and an absolute love of performing on stage, created within me, a voice. Semantic Score:  0.4094
#
# Program Tone Sentence #1: Everywhere I go, I aim to inspire those I meet to step into their authenticity, and live with unshakeable joy. Tone Score:  0.8937
# Program Tone Sentence #2: As an artist, being creative was not only a huge aspect of my recovery, but is one of the ways I remain healthy. Tone Score:  0.8856
# Program Tone Sentence #3: In this interview with Raelan Agle, I share my journey with MECFS; the good, the bad, the ugly, the beautiful, and most of all, the redemption. Tone Score:  0.8777
# Program Tone Sentence #4: That’s why I created The Edison Effect; for the same reason I create anything; to experience and facilitate connection with others. Tone Score:  0.8763
# Program Tone Sentence #5: I hope my truth, the reality of my life before, during and after MECFS, helps liberate you to embrace the darkest, most forgotten parts of yourself, that voice inside, that wants to be heard; wants to be free. Tone Score:  0.8716
#
#
#
#
#
#
# DNRS
# I want to be healthy and happy
# Program Semantic Sentence #1: If you consistently apply these principles, you will go FAR toward your goal of optimal health. Semantic Score:  0.4462
# Program Semantic Sentence #2: However, moving into a state of growth requires that we provide the brain and body with a context of safety, and we can do so by choosing to cultivate and soak our brains and bodies with the chemical signature produced by positive emotions. Semantic Score:  0.3707
# Program Semantic Sentence #3: We are here to support you along the way with guidance, connection, motivation and accountability as you learn to successfully Retrain Your Brain, Regain Your Health, and Reclaim Your Life. Semantic Score:  0.3195
# Program Semantic Sentence #4: Emotions are powerful signalling molecules that send a message to the cell and DNA within the cell what to do – should I be in a growth state, or should I be in a protective state? Semantic Score:  0.3130
# Program Semantic Sentence #5: We provide a breakdown of their discussion on the science behind boosting your emotional state, and why it matters when it comes to health and healing. Semantic Score:  0.2844
#
# Program Tone Sentence #1: The more time we spend soaking and marinating in this state, the greater the benefit on our health and our emotional well-being! Tone Score:  0.8344
# Program Tone Sentence #2: We have seen countless lifelong friendships formed with people from around the world who met on the forum. Tone Score:  0.7835
# Program Tone Sentence #3: Founder of the DNRS program Annie Hopper, and the coaching team took a deep dive into exploring the realm of emotions and the work of Dr. Candace Pert, a former professor at the Georgetown School of Medicine, author of Molecules of Emotion, Everything You Need to Know to Feel Go(o)d, and more than 250 scientific articles. Tone Score:  0.7807
# Program Tone Sentence #4: Inside the forum, you will also find unparalleled inspiration, motivation and support from fellow DNRS participants. Tone Score:  0.7791
# Program Tone Sentence #5: We also invite you to subscribe to our monthly newsletter where we share new research and articles as well as inspiring new testimonials from the DNRS community. Tone Score:  0.7771
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: Remove any distractions that could get in the way of you giving your undivided attention. Semantic Score:  0.3236
# Program Semantic Sentence #2: We provide a breakdown of their discussion on the science behind boosting your emotional state, and why it matters when it comes to health and healing. Semantic Score:  0.3139
# Program Semantic Sentence #3: Using a support service like our Share-a-Laugh classes, doing full rounds of the DNRS retraining steps, and listening to uplifting music can assist you greatly in this endeavour. Semantic Score:  0.3012
# Program Semantic Sentence #4: Pillar 5: Elevate Your Emotional State:  Elevating your emotional state helps to provide a cue of safety to the brain, allowing for the brain to move out of survival-related emotions and pave the way for positive neuroplastic changes. Semantic Score:  0.3008
# Program Semantic Sentence #5: Emotions are powerful signalling molecules that send a message to the cell and DNA within the cell what to do – should I be in a growth state, or should I be in a protective state? Semantic Score:  0.2877
#
# Program Tone Sentence #1: The most common emotions associated with limbic system impairment are fear, sadness, despair, anger, hopelessness, and worry. Tone Score:  0.9149
# Program Tone Sentence #2: In the beginning, cultivating a positive emotional state when you are suffering from limbic system impairment can seem challenging. Tone Score:  0.8076
# Program Tone Sentence #3: Lingering negative emotions may indicate a stuck survival response, (as seen with limbic system impairment) or the story we attach to it. Tone Score:  0.7720
# Program Tone Sentence #4: The Dynamic Neural Retraining System is a self-guided brain retraining program that uses the principles of neuroplasticity to help reverse limbic system impairment and regulate a maladaptive chronic stress response that is often the cause of a long list of chronic conditions and symptoms. Tone Score:  0.7616
# Program Tone Sentence #5: Remember, this is not the person’s fault – the brain may be stuck in a survival response. Tone Score:  0.6666
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: However, moving into a state of growth requires that we provide the brain and body with a context of safety, and we can do so by choosing to cultivate and soak our brains and bodies with the chemical signature produced by positive emotions. Semantic Score:  0.5370
# Program Semantic Sentence #2: Emotions are powerful signalling molecules that send a message to the cell and DNA within the cell what to do – should I be in a growth state, or should I be in a protective state? Semantic Score:  0.4305
# Program Semantic Sentence #3: This is an awareness exercise that allows you to identify and change patterns of thinking, feeling and behaving to support the creation of new neural pathways. Semantic Score:  0.3874
# Program Semantic Sentence #4: Positive emotions pave the way for moving the cell into a growth state, where substances can enter the cell and signal the DNA to create proteins needed for regeneration and repair. Semantic Score:  0.3781
# Program Semantic Sentence #5: We provide a breakdown of their discussion on the science behind boosting your emotional state, and why it matters when it comes to health and healing. Semantic Score:  0.3661
#
# Program Tone Sentence #1: With time and repetition, we can change our emotional landscape and gain greater access to the full realm of emotions, in a healthy and balanced way. Tone Score:  0.9021
# Program Tone Sentence #2: However, moving into a state of growth requires that we provide the brain and body with a context of safety, and we can do so by choosing to cultivate and soak our brains and bodies with the chemical signature produced by positive emotions. Tone Score:  0.9008
# Program Tone Sentence #3: Keep in mind that we are shifting not just to peace and calm but shifting the emotional pendulum all the way to a sense of joy, connection, love, awe or gratitude. Tone Score:  0.8852
# Program Tone Sentence #4: Positive emotions pave the way for moving the cell into a growth state, where substances can enter the cell and signal the DNA to create proteins needed for regeneration and repair. Tone Score:  0.8715
# Program Tone Sentence #5: Before you begin the program, make sure you have prepared an effective learning environment for yourself. Tone Score:  0.8707
#
#
#
#
#
#
# The Gupta Program
# I want to be healthy and happy
# Program Semantic Sentence #1: Don’t treat yourself like a machine. Give your mind and body the regular rest it deserves. And don’t buy into your expectations of yourself. This is real self-love. Semantic Score:  0.4453
# Program Semantic Sentence #2: When you're compassionate with yourself and you're loving towards yourself, that's when you will truly discover that it's much easier to be inspired every day to live your potential and be healthier and happier. Semantic Score:  0.4158
# Program Semantic Sentence #3: On topics such as diet, sleep, nutrition, mindfulness and pacing Get motivation & support throughout every step of your healing journey and have your questions answered directly by Ashok. Semantic Score:  0.3549
# Program Semantic Sentence #4: This process has incredible benefits for both our mental and physical health. Semantic Score:  0.3517
# Program Semantic Sentence #5: Access to trained Gupta Program Coaches to tailor the program to your needs Full of like-minded individuals dedicated to health to help to support you through your recovery Semantic Score:  0.3362
#
# Program Tone Sentence #1: This process has incredible benefits for both our mental and physical health. Tone Score:  0.7820
# Program Tone Sentence #2: When you're compassionate with yourself and you're loving towards yourself, that's when you will truly discover that it's much easier to be inspired every day to live your potential and be healthier and happier. Tone Score:  0.7769
# Program Tone Sentence #3: For instance, I really encourage you to read uplifting self-development books. Tone Score:  0.7742
# Program Tone Sentence #4: Neuroplasticity is one of the hottest topics in neuroscience and has far-reaching implications & potential for most aspects of our lives. Tone Score:  0.7533
# Program Tone Sentence #5: These easy to access resources will help deepen your recovery further. Tone Score:  0.7500
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: You have permission to rest. You are not responsible for fixing everything that is broken. You do not have to try to make everyone happy. For now, take time for you. It's time to replenish. Semantic Score:  0.4017
# Program Semantic Sentence #2: We feel like we just want to take a rest. Semantic Score:  0.3751
# Program Semantic Sentence #3: Don’t treat yourself like a machine. Give your mind and body the regular rest it deserves. And don’t buy into your expectations of yourself. This is real self-love. Semantic Score:  0.3703
# Program Semantic Sentence #4: If you don’t fill your mind with positive engaging distracting activities, the mind will default to worry. Semantic Score:  0.3532
# Program Semantic Sentence #5: This causes the amygdala – the part of the brain responsible for the stress response – to become hypersensitive. Semantic Score:  0.3157
#
# Program Tone Sentence #1: We feel like we just want to take a rest. Tone Score:  0.8422
# Program Tone Sentence #2: It is estimated that at least 2% to 5% of the population suffer from Fibromyalgia, a complex pain condition in some form, and until now there has been a lack of effective treatments. Tone Score:  0.8215
# Program Tone Sentence #3: For instance, when we have flu, our immune system is triggered but this also has an effect on our emotions and how we feel. Tone Score:  0.8161
# Program Tone Sentence #4: Learn more the range of physical, cognitive and emotional symptoms that those with ME/CFS, fibromyalgia, and associated illnesses may experience – explaining how they may be products of amygdala hyper-sensitization. Tone Score:  0.7802
# Program Tone Sentence #5: Many chronic conditions are known to begin with a stressor, trauma, or illness such as a virus. Tone Score:  0.7695
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: When you're compassionate with yourself and you're loving towards yourself, that's when you will truly discover that it's much easier to be inspired every day to live your potential and be healthier and happier. Semantic Score:  0.4938
# Program Semantic Sentence #2: For instance, I really encourage you to read uplifting self-development books. Semantic Score:  0.4263
# Program Semantic Sentence #3: This process has incredible benefits for both our mental and physical health. Semantic Score:  0.3756
# Program Semantic Sentence #4: These connections are created by exposure to new experiences and challenges. Semantic Score:  0.3467
# Program Semantic Sentence #5: By understanding how neuroplasticity works, we can harness this ability to make positive changes to our mental and physical health. Semantic Score:  0.3273
#
# Program Tone Sentence #1: When you're compassionate with yourself and you're loving towards yourself, that's when you will truly discover that it's much easier to be inspired every day to live your potential and be healthier and happier. Tone Score:  0.8902
# Program Tone Sentence #2: For instance, I really encourage you to read uplifting self-development books. Tone Score:  0.8899
# Program Tone Sentence #3: These connections are created by exposure to new experiences and challenges. Tone Score:  0.8813
# Program Tone Sentence #4: And biologically this is to ensure that healing occurs so that we survive. Tone Score:  0.8766
# Program Tone Sentence #5: On topics such as diet, sleep, nutrition, mindfulness and pacing Get motivation & support throughout every step of your healing journey and have your questions answered directly by Ashok. Tone Score:  0.8684
#
#
#
#
#
#
# Vital Side: Rewire
# I want to be healthy and happy
# Program Semantic Sentence #1: Make sure to take care of yourself by spending time outside and talking to someone professional if you need it. Semantic Score:  0.4212
# Program Semantic Sentence #2: Adding these practices to your daily routine boosts how good you feel overall and improves your life. Semantic Score:  0.3974
# Program Semantic Sentence #3: By looking after your body, mind, relationships, and spiritual side, you can handle stress better and keep a good balance of feelings and thoughts. Semantic Score:  0.3780
# Program Semantic Sentence #4: You'll learn how to increase dopamine, oxytocin, serotonin, and endorphins to get your "daily dose". Semantic Score:  0.3731
# Program Semantic Sentence #5: You'll start to identify goals you have for yourself as you begin to understand the possibilities available to you today. Semantic Score:  0.3649
#
# Program Tone Sentence #1: These include breathwork, picturing calming scenes in your mind, thinking positively, making time to be outside and more. Tone Score:  0.8158
# Program Tone Sentence #2: It even improves heart rate variability and boosts the overall health of your heart. Tone Score:  0.8142
# Program Tone Sentence #3: Adding these practices to your daily routine boosts how good you feel overall and improves your life. Tone Score:  0.7995
# Program Tone Sentence #4: This leads not only to feeling more balanced but also to living a happier life with the help of the Nervous System Solution. Tone Score:  0.7938
# Program Tone Sentence #5: Even something as simple as a quick stroll through the park or a hike among trees can do wonders for how you feel inside and improve the functioning of your brain. Tone Score:  0.7892
#
#
# I feel stressed, but I don't know what to do with it
# Program Semantic Sentence #1: By getting deep into your thoughts, you can spot patterns or links that affect how calm or stressed you feel. Semantic Score:  0.5391
# Program Semantic Sentence #2: When your nervous system is out of whack, you might notice things like your heart beating fast, your hands getting sweaty, feeling really stressed all the time or dealing with stress that just doesn't go away. Semantic Score:  0.5262
# Program Semantic Sentence #3: Alt text: Girl doing Deep breath exerciseSource When you're feeling stressed, one of the quickest and most effective nervous system regulation exercises is taking deep breaths. Semantic Score:  0.5135
# Program Semantic Sentence #4: If things get out of balance, chronic stress can mess with your physical health, causing issues such as high blood pressure or ongoing pain. Semantic Score:  0.4976
# Program Semantic Sentence #5: These include breathwork, picturing calming scenes in your mind, thinking positively, making time to be outside and more. Semantic Score:  0.4605
#
# Program Tone Sentence #1: This can make a person feel super stressed, have sudden mood changes, and find it hard to control their emotions. Tone Score:  0.9135
# Program Tone Sentence #2: When your nervous system is out of whack, you might notice things like your heart beating fast, your hands getting sweaty, feeling really stressed all the time or dealing with stress that just doesn't go away. Tone Score:  0.9089
# Program Tone Sentence #3: Signs of a dysregulated nervous system can manifest in various ways, including constant feelings of stress or anxiety, difficulty focusing or sleeping, mood swings, digestive issues, and chronic fatigue. Tone Score:  0.8764
# Program Tone Sentence #4: Imbalances caused by chronic stress, past traumas, or mental health conditions can disrupt this equilibrium. Tone Score:  0.8282
# Program Tone Sentence #5: When you've been battling chronic symptoms for months or years, you feel like you've tried everything under the sun to heal. Tone Score:  0.8262
#
#
# I care deeply about growing as a person
# Program Semantic Sentence #1: This way, you get better at understanding how you feel inside. Semantic Score:  0.4235
# Program Semantic Sentence #2: You'll start to identify goals you have for yourself as you begin to understand the possibilities available to you today. Semantic Score:  0.4221
# Program Semantic Sentence #3: Using applied positive psychology, we'll focus on character strengths & behaviors that allow us to build a life of meaning & purpose and go from surviving to thriving. Semantic Score:  0.3757
# Program Semantic Sentence #4: When you do this, you're basically getting in touch with how you feel on the inside, which helps you know yourself more. Semantic Score:  0.3687
# Program Semantic Sentence #5: You'll become aware of old beliefs that keep you held back and how they show up in your life. Semantic Score:  0.3627
#
# Program Tone Sentence #1: This way, you get better at understanding how you feel inside. Tone Score:  0.9001
# Program Tone Sentence #2: When you do this, you're basically getting in touch with how you feel on the inside, which helps you know yourself more. Tone Score:  0.8838
# Program Tone Sentence #3: With practice, we can get better at controlling our feelings and feeling happier overall. Tone Score:  0.8825
# Program Tone Sentence #4: One important thing to know about how our bodies work is the idea of being connected. Tone Score:  0.8818
# Program Tone Sentence #5: Using applied positive psychology, we'll focus on character strengths & behaviors that allow us to build a life of meaning & purpose and go from surviving to thriving. Tone Score:  0.8761

# %%
#Now let's pull out the top ten matches for each program, regardless of user sentence

summary = {'Name': [], 
           'Semantic Sentences': [], 'User Semantic Sentences':[], 'Semantic Scores':[], 'Avg Semantic Score': [],
           'Tone Sentences':[], 'User Tone Sentences':[], 'Tone Scores':[], 'Avg Tone Score': [],
           'Overall Score':[]}
for p in range(N_progs): #for each program
    summary['Name'].append(program_list[p].name)
    
    flat_sem_scores = topsem_score[p].flatten() #flatten the scores for sorting
    flat_sem_indx = topsem_indx[p].flatten() #flatten the sentence indices for reference after sorting
    flat_tone_scores = toptone_score[p].flatten()
    flat_tone_indx = toptone_indx[p].flatten()
    
    topsem_indx = tf.argsort(flat_sem_scores,direction='DESCENDING')[:10] #get indices of the top ten scores
    topsem_scores = [flat_sem_scores[indx] for indx in topsem_indx] #get the top ten scores
    topsem_sent_indx = [int(flat_sem_indx[indx]) for indx in topsem_indx] #get the indices for the top ten sentences
    sem_sentences = [program_list[p].text[indx] for indx in topsem_sent_indx] #get the top ten sentences
    user_sem_indx = np.floor([indx/N_similarities for indx in topsem_indx]).astype(int)
    user_sem_sentences = [UserText[indx] for indx in user_sem_indx]
    
    toptone_indx = tf.argsort(flat_tone_scores,direction='DESCENDING')[:10]
    toptone_scores = [flat_tone_scores[indx] for indx in toptone_indx] #get the top ten scores
    toptone_sent_indx = [int(flat_tone_indx[indx]) for indx in toptone_indx] #get the indices for the top ten sentences
    tone_sentences = [program_list[p].text[indx] for indx in toptone_sent_indx] #get the top ten sentences
    user_tone_indx = np.floor([indx/N_similarities for indx in toptone_indx]).astype(int)
    user_tone_sentences = [UserText[indx] for indx in user_tone_indx]
    
    overall_score = (0.5)*np.mean(topsem_scores) + (0.5)*np.mean(toptone_scores) #for now, equal weights to semantic and tone scores
    
    summary['Semantic Sentences'].append(sem_sentences)
    summary['User Semantic Sentences'].append(user_sem_sentences)
    summary['Semantic Scores'].append(topsem_scores)
    summary['Avg Semantic Score'].append(np.mean(topsem_scores))
    
    summary['Tone Sentences'].append(tone_sentences)
    summary['User Tone Sentences'].append(user_tone_sentences)
    summary['Tone Scores'].append(toptone_scores)
    summary['Avg Tone Score'].append(np.mean(toptone_scores))
    
    summary['Overall Score'].append(overall_score)

# %%
top3_indx = tf.argsort(summary['Overall Score'],direction='DESCENDING')[:3]
for i in top3_indx:
    print(f"{summary['Name'][i]}, (Overall Score {summary['Overall Score'][i]:.4f})")
    print("-"*50)
    print(f"Average Semantic Score: {summary['Avg Semantic Score'][i]:.4f}")
    for j in range(len(summary['Semantic Scores'][i])):
        print(f"PROGRAM SENTENCE: {summary['Semantic Sentences'][i][j]}")
        print(f"USER SENTENCE: {summary['User Semantic Sentences'][i][j]}")
        print(f"SEMANTIC SCORE: {summary['Semantic Scores'][i][j]:.4f}")
    print(f"\nAverage Tone Score: {summary['Avg Tone Score'][i]:.4f}")
    for j in range(len(summary['Tone Scores'][i])):
        print(f"PROGRAM SENTENCE: {summary['Tone Sentences'][i][j]}")
        print(f"USER SENTENCE: {summary['User Tone Sentences'][i][j]}")
        print(f"TONE SCORE: {summary['Tone Scores'][i][j]:.4f}")
    print('\n\n')
# Out:
# Vital Side: Rewire, (Overall Score 0.6678)
# --------------------------------------------------
# Average Semantic Score: 0.4579
# PROGRAM SENTENCE: By getting deep into your thoughts, you can spot patterns or links that affect how calm or stressed you feel.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.5391
# PROGRAM SENTENCE: When your nervous system is out of whack, you might notice things like your heart beating fast, your hands getting sweaty, feeling really stressed all the time or dealing with stress that just doesn't go away.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.5262
# PROGRAM SENTENCE: Alt text: Girl doing Deep breath exerciseSource When you're feeling stressed, one of the quickest and most effective nervous system regulation exercises is taking deep breaths.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.5135
# PROGRAM SENTENCE: If things get out of balance, chronic stress can mess with your physical health, causing issues such as high blood pressure or ongoing pain.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.4976
# PROGRAM SENTENCE: These include breathwork, picturing calming scenes in your mind, thinking positively, making time to be outside and more.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.4605
# PROGRAM SENTENCE: This way, you get better at understanding how you feel inside.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4235
# PROGRAM SENTENCE: You'll start to identify goals you have for yourself as you begin to understand the possibilities available to you today.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4221
# PROGRAM SENTENCE: Make sure to take care of yourself by spending time outside and talking to someone professional if you need it.
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.4212
# PROGRAM SENTENCE: Adding these practices to your daily routine boosts how good you feel overall and improves your life.
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.3974
# PROGRAM SENTENCE: By looking after your body, mind, relationships, and spiritual side, you can handle stress better and keep a good balance of feelings and thoughts.
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.3780
#
# Average Tone Score: 0.8777
# PROGRAM SENTENCE: This can make a person feel super stressed, have sudden mood changes, and find it hard to control their emotions.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.9135
# PROGRAM SENTENCE: When your nervous system is out of whack, you might notice things like your heart beating fast, your hands getting sweaty, feeling really stressed all the time or dealing with stress that just doesn't go away.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.9089
# PROGRAM SENTENCE: This way, you get better at understanding how you feel inside.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.9001
# PROGRAM SENTENCE: When you do this, you're basically getting in touch with how you feel on the inside, which helps you know yourself more.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8838
# PROGRAM SENTENCE: With practice, we can get better at controlling our feelings and feeling happier overall.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8825
# PROGRAM SENTENCE: One important thing to know about how our bodies work is the idea of being connected.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8818
# PROGRAM SENTENCE: Signs of a dysregulated nervous system can manifest in various ways, including constant feelings of stress or anxiety, difficulty focusing or sleeping, mood swings, digestive issues, and chronic fatigue.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8764
# PROGRAM SENTENCE: Using applied positive psychology, we'll focus on character strengths & behaviors that allow us to build a life of meaning & purpose and go from surviving to thriving.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8761
# PROGRAM SENTENCE: Imbalances caused by chronic stress, past traumas, or mental health conditions can disrupt this equilibrium.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8282
# PROGRAM SENTENCE: When you've been battling chronic symptoms for months or years, you feel like you've tried everything under the sun to heal.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8262
#
#
#
# re-origin, (Overall Score 0.6350)
# --------------------------------------------------
# Average Semantic Score: 0.3967
# PROGRAM SENTENCE: Instead, it becomes your foundation for growth.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.5036
# PROGRAM SENTENCE: Say to yourself: “This is hard, and I’m doing my best,” or “I can feel this emotion without it controlling me.” These phrases foster true acceptance and soothe the nervous system.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.4601
# PROGRAM SENTENCE: This ability to change helps promote: The ability to learn new things.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4120
# PROGRAM SENTENCE: For many individuals, a turning point in their healing path comes not from trying to change their condition but from changing their relationship with it.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4068
# PROGRAM SENTENCE: Talking to others, sharing your experience, and receiving compassion can help you feel accepted and understood.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.3766
# PROGRAM SENTENCE: The combination of stressors essentially overwhelms the brain, causing it to go into an extreme survival mode in which it’s hypersensitive and hyper-reactive.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3760
# PROGRAM SENTENCE: Rather than trying to change these internal experiences, ACT invites individuals to live in alignment with their values—despite the presence of pain.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.3753
# PROGRAM SENTENCE: Instead of focusing on what you can’t do, ask: “What small action can I take today that supports my personal growth and health?” Mindfulness and brain retraining practices help you develop new associations with your symptoms and shift into a more accepting mindset over time.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3627
# PROGRAM SENTENCE: You can re-train your brain toward health with a few simple techniques.
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.3573
# PROGRAM SENTENCE: Chronic stress, fear, and resistance can keep the nervous system in a state of hypervigilance.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3369
#
# Average Tone Score: 0.8733
# PROGRAM SENTENCE: Talking to others, sharing your experience, and receiving compassion can help you feel accepted and understood.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.9013
# PROGRAM SENTENCE: The re-origin program is designed to help you change your relationship with your chronic illness while cultivating opportunities for healing and growth.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8906
# PROGRAM SENTENCE: The main idea of acceptance is acknowledging and allowing experiences, emotions, or situations as they are—without judgment or resistance—so we can respond with clarity, compassion, and purpose.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8885
# PROGRAM SENTENCE: This ability to change helps promote: The ability to learn new things.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8880
# PROGRAM SENTENCE: Plus, re-origin offers access to a community and coaching specifically geared towards helping people retrain their own brains and return to feeling like themselves.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8818
# PROGRAM SENTENCE: Chronic illness often creates uncertainty, loss, and profound shifts in identity.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8710
# PROGRAM SENTENCE: Recovery from limbic system impairments, commonly resulting in fibromyalgia, CFS/ME, and depression.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8637
# PROGRAM SENTENCE: Designed for people suffering from anxiety, depression, long COVID, Lyme Disease, chronic fatigue syndrome, multiple chemical sensitivity, fibromyalgia, chronic pain, and many other conditions.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8620
# PROGRAM SENTENCE: Changes to this system can lead to a wide variety of negative symptoms and conditions, such as depression, anxiety, OCD, sensitivities, chronic pain, and chronic fatigue syndrome, just to name a few.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8511
# PROGRAM SENTENCE: In many cases, limbic system impairments arise when someone experiences a traumatic event while their chronic stress load is already high.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8351
#
#
#
# The Edison Effect, (Overall Score 0.6247)
# --------------------------------------------------
# Average Semantic Score: 0.3888
# PROGRAM SENTENCE: I was a tiny person with enormous feelings.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4941
# PROGRAM SENTENCE: This sensitivity also made me an incredible artist, a wonderful story-teller, a poet and composer, and an endlessly curious, open-hearted soul, who is capable of giving life to other's experiences in word and song.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4445
# PROGRAM SENTENCE: Everywhere I go, I aim to inspire those I meet to step into their authenticity, and live with unshakeable joy.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4242
# PROGRAM SENTENCE: It made me someone people loved to talk to; to vent to, to lean on.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4150
# PROGRAM SENTENCE: Best of all, this sensitivity, mixed with a gift for language, and an absolute love of performing on stage, created within me, a voice.
# USER SENTENCE: I care deeply about growing as a person
# SEMANTIC SCORE: 0.4094
# PROGRAM SENTENCE: A stress response that through conditioning and through crashes, has become more highly sensitive, resulting in a greater imbalance in the way it's triggered, and also greater physiological distress, CAN be reshaped through neuroplasticity and returned to normal.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3742
# PROGRAM SENTENCE: Whatever we do, we must try to help the body return to homeostasis.
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.3595
# PROGRAM SENTENCE: What I was taught at the institute, is that because homeostasis has been lost, and the stress response and rest/digest response are both not working properly, we must work as we can to normalize the stress response, so the body can find balance.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3503
# PROGRAM SENTENCE: However, the reason we work with the ANS the most, is because, without dealing with our stress response, all the other systems which can be so greatly impacted by holistic methods and functional medicine (like the $15,000 I spent on HBOT and ozone therapy which truly helped), will get shot to hell if we have a huge stress trigger again.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# SEMANTIC SCORE: 0.3092
# PROGRAM SENTENCE: With my health restored, I am now living my dreams of nomadically traveling the world!
# USER SENTENCE: I want to be healthy and happy
# SEMANTIC SCORE: 0.3082
#
# Average Tone Score: 0.8606
# PROGRAM SENTENCE: Everywhere I go, I aim to inspire those I meet to step into their authenticity, and live with unshakeable joy.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8937
# PROGRAM SENTENCE: As an artist, being creative was not only a huge aspect of my recovery, but is one of the ways I remain healthy.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8856
# PROGRAM SENTENCE: In this interview with Raelan Agle, I share my journey with MECFS; the good, the bad, the ugly, the beautiful, and most of all, the redemption.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8777
# PROGRAM SENTENCE: That’s why I created The Edison Effect; for the same reason I create anything; to experience and facilitate connection with others.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8763
# PROGRAM SENTENCE: I hope my truth, the reality of my life before, during and after MECFS, helps liberate you to embrace the darkest, most forgotten parts of yourself, that voice inside, that wants to be heard; wants to be free.
# USER SENTENCE: I care deeply about growing as a person
# TONE SCORE: 0.8716
# PROGRAM SENTENCE: It made me resentful and melancholy.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8689
# PROGRAM SENTENCE: After a lifetime of trauma, heartache and distress, I had my first crash in 2018, which led to pushing and crashing until 2021, when a severe crash left me both neurologically and physically crippled.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8578
# PROGRAM SENTENCE: Looking back now, I experienced fatigue as early as my teens, and it's rare to find a picture of me as a kid without a tissue in hand.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8360
# PROGRAM SENTENCE: Without the tools, I experienced at young age,  great anxiety and fear about the world around me.
# USER SENTENCE: I feel stressed, but I don't know what to do with it
# TONE SCORE: 0.8238
# PROGRAM SENTENCE: Connection is the source of all joy.
# USER SENTENCE: I want to be healthy and happy
# TONE SCORE: 0.8142

# %%
xtest['name'].append('Jack')

# %%
print(xtest)
# Out:
# {'name': ['Jack', 'Jack'], 'scores': [], 'avg': []}

# %%
#Initialize semantic_similarities = []*N_UserEmbeddings
#Initialize tone_similarities = []*N_UserEmbeddings
#for prog in programlist:
# prog_semantic_similarities = np.zeros(np.shape(prog.tone_embeddings)[0],N_UserEmbedding)
# prog_semantic_similarities = np.zeros(np.shape(prog.tone_embeddings)[0],N_UserEmbedding)
#  for i in np.shape(UserSemanticEmbeddings)[0]: 
# for emb in prog.semantic_embeddings:
#  cosinesimilarity(UserSemanticEmbeddings[i],Emb)
# for emb in prog.tone_embeddings:
#  cosinesimilarity(UserToneEmbeddings[i],Emb)
#
